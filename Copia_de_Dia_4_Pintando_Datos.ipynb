# %% [markdown]
# <a href="https://colab.research.google.com/github/durandaniel2031-jpg/prueba2/blob/main/Copia_de_Dia_4_Pintando_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Día 4: Interactividad y Gráficos Vivos (Plotly)
# **Key Summer Camp 2026 | Track de Programación**
#
# ¡Ayer hicieron historia! Cada uno de ustedes logró crear y personalizar sus propios gráficos estáticos. Pero hoy vamos a llevarlo al siguiente nivel.
#
# Hoy dejaremos atrás las "imágenes planas" y aprenderemos a usar **Plotly**. Esta herramienta nos permite crear gráficos **interactivos**: podrán pasar el ratón por encima, hacer zoom y explorar los datos del torneo en tiempo real.
#
# > 🚨 **Punto de Control:** Asegúrate de subir `smash_dataset_clean.csv` a la carpeta de la izquierda antes de iniciar.

# %%
import pandas as pd
import sqlite3
import plotly.express as px
df_torneo = pd.read_csv("smash_dataset_clean.csv", encoding="latin1")
conexion = sqlite3.connect("torneo_smash.db")
df_torneo.to_sql("combates", conexion, if_exists="replace", index=False)
df_graficos = pd.read_sql_query("SELECT * FROM combates", conexion)
print("✅ Datos interactivos listos y cargados en memoria.")
# Out:
# ✅ Datos interactivos listos y cargados en memoria.

# %% [markdown]
# ## ⚖️ Misión 1: El Mapa Táctico Interactivo (Riesgo vs Recompensa)
# Vamos a hacer un **Gráfico de Dispersión Interactivo**. La ventaja de Plotly es que, al pasar el cursor sobre un punto, ¡nos dirá exactamente qué jugador es y qué personaje usó sin tener que adivinar!

# %%
grafico_dispersion = px.scatter(
    df_graficos,
    x="Edad",
    y="Muertes",
    color="Personaje",
    size="Muertes",
    hover_data=["Sexo", "Nombre", "Muertes", "Personaje"],
    title=" Análisis de personajes usados segun sexo y edad",
    template="plotly_dark",
    size_max=20
)
grafico_dispersion.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="167cfee7-1cb8-4fa5-9b64-bb3f1e888926" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("167cfee7-1cb8-4fa5-9b64-bb3f1e888926")) {                    Plotly.newPlot(                        "167cfee7-1cb8-4fa5-9b64-bb3f1e888926",                        [{"customdata":[["Hombre","Gabriel","Little mac"],["Hombre","Gabriel","Little mac"]],"hovertemplate":"Personaje=%{customdata[2]}\u003cbr\u003eEdad=%{x}\u003cbr\u003eMuertes=%{marker.size}\u003cbr\u003eSexo=%{customdata[0]}\u003cbr\u003eNombre=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Little mac","marker":{"color":"#636efa","size":[1.0,2.0],"sizemode":"area","sizeref":0.01,"symbol":"circle"},"mode":"markers","name":"Little mac","orientation":"v","showlegend":true,"x":[15,15],"xaxis":"x","y":[1.0,2.0],"yaxis":"y","type":"scatter"},{"customdata":[["Hombre","Adrian","Incineroar"],["Hombre","Mateo","Incineroar"]],"hovertemplate":"Personaje=%{customdata[2]}\u003cbr\u003eEdad=%{x}\u003cbr\u003eMuertes=%{marker.size}\u003cbr\u003eSexo=%{customdata[0]}\u003cbr\u003eNombre=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Incineroar","marker":{"color":"#EF553B","size":[2.0,1.0],"sizemode":"area","sizeref":0.01,"symbol":"circle"},"mode":"markers","name":"Incineroar","orientation":"v","showlegend":true,"x":[13,13],"xaxis":"x","y":[2.0,1.0],"yaxis":"y","type":"scatter"},{"customdata":[["Hombre","Ale","Kirby"],["Mujer","maria jose","Kirby"],["Mujer","Laura ","Kirby"],["Hombre","Josue","Kirby"],["Hombre","Jonathan","Kirby"],["Mujer","maria jose","Kirby"]],"hovertemplate":"Personaje=%{customdata[2]}\u003cbr\u003eEdad=%{x}\u003cbr\u003eMuertes=%{marker.size}\u003cbr\u003eSexo=%{customdata[0]}\u003cbr\u003eNombre=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kirby","marker":{"color":"#00cc96","size":[2.0,1.0,2.0,1.0,1.0,1.0],"sizemode":"area","sizeref":0.01,"symbol":"circle"},"mode":"markers","name":"Kirby","orientation":"v","showlegend":true,"x":[13,15,16,19,19,15],"xaxis":"x","y":[2.0,1.0,2.0,1.0,1.0,1.0],"yaxis":"y","type":"scatter"},{"customdata":[["Hombre","Leonardo","shulk"]],"hovertemplate":"Personaje=%{customdata[2]}\u003cbr\u003eEdad=%{x}\u003cbr\u003eMuertes=%{marker.size}\u003cbr\u003eSexo=%{customdata[0]}\u003cbr\u003eNombre=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"shulk","marker":{"color":"#ab63fa","size":[2.0],"sizemode":"area","sizeref":0.01,"symbol":"circle"},"mode":"markers","name":"shulk","orientation":"v","showlegend":true,"x":[13],"xaxis":"x","y":[2.0],"yaxis":"y","type":"scatter"},{"customdata":[["Hombre","Carlos","Game and watch "]],"hovertemplate":"Personaje=%{customdata[2]}\u003cbr\u003eEdad=%{x}\u003cbr\u003eMuertes=%{marker.size}\u003cbr\u003eSexo=%{customdata[0]}\u003cbr\u003eNombre=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Game and watch ","marker":{"color":"#FFA15A","size":[1.0],"sizemode":"area","sizeref":0.01,"symbol":"circle"},"mode":"markers","name":"Game and watch ","orientation":"v","showlegend":true,"x":[16],"xaxis":"x","y":[1.0],"yaxis":"y","type":"scatter"},{"customdata":[["Hombre","Andres","R0B"]],"hovertemplate":"Personaje=%{customdata[2]}\u003cbr\u003eEdad=%{x}\u003cbr\u003eMuertes=%{marker.size}\u003cbr\u003eSexo=%{customdata[0]}\u003cbr\u003eNombre=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R0B","marker":{"color":"#19d3f3","size":[1.0],"sizemode":"area","sizeref":0.01,"symbol":"circle"},"mode":"markers","name":"R0B","orientation":"v","showlegend":true,"x":[13],"xaxis":"x","y":[1.0],"yaxis":"y","type":"scatter"},{"customdata":[["Hombre","Julian","Daisy"]],"hovertemplate":"Personaj ...

# %% [markdown]
# ## 🍩 Misión 2: El Gráfico de Dona (La Meta del Torneo)
# Vamos a descubrir qué personajes fueron los más elegidos en todo el campamento usando un gráfico circular especial con un agujero en el centro.

# %%
grafico_dona = px.pie(
    df_graficos,
    names="Edad",
    hole=0.4,
    title=" edades mas comunes de el torneo",
    template="plotly_dark"
)
grafico_dona.update_traces(marker=dict(line=dict(color='#000000', width=2)))
grafico_dona.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c6459b27-20b6-44f3-99ab-f497f21e762d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6459b27-20b6-44f3-99ab-f497f21e762d")) {                    Plotly.newPlot(                        "c6459b27-20b6-44f3-99ab-f497f21e762d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Edad=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":[15,13,13,13,16,13,13,13,14,14,13,15,21,20,16,14,19,19,19,13,15,21,15,16],"legendgroup":"","name":"","showlegend":true,"type":"pie","marker":{"line":{"color":"#000000","width":2}}}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# ---
# ## 💾 Guardado y Preparación para el Boss Final
# ¡Excelente trabajo! Han dominado la visualización interactiva. Esta es la base exacta de lo que usan empresas gigantes para analizar sus datos.
#
# Guarden su trabajo en GitHub (`Archivo -> Guardar una copia en GitHub`).
# **Mensaje del Commit:** `"Día 4: Gráficos Interactivos con Plotly"`.
#
# **🔥 TEASER PARA MAÑANA:**
# Mañana es el Hackathon Final. Vamos a tomar estos gráficos interactivos y, usando **Streamlit**, los convertiremos en una **Aplicación Web real y pública** a la que cualquiera podrá entrar desde su celular. ¡Descansen, porque mañana construimos software de verdad!
