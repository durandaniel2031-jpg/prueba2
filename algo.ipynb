# %% [markdown]
# <a href="https://colab.research.google.com/github/durandaniel2031-jpg/prueba2/blob/main/algo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("esta cosa esta en español")
# Out:
# esta cosa esta en español

# %%
print ("donde esta el / al reves en esta cosa")
# Out:
# donde esta el / al reves en esta cosa

# %%
jugador = "meta knight"

# %%
print (jugador,"lo acaban de chingar")
# Out:
# meta knight lo acaban de chingar

# %%
jugador2 = "ridley"

# %%
print (jugador,"lo acaban de chingar")
# Out:
# meta knight lo acaban de chingar

# %%
print (jugador2,"juega horrible")
# Out:
# ridley juega horrible
